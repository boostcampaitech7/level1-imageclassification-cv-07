# %%
import pandas as pd
df1=pd.read_csv('coatnet_3_rw_224_5fold.csv')
df2=pd.read_csv('vit_coat_eff_3fold.csv')
df3=pd.read_csv('coatnet_3_rw_224_3fold.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       2 df1=pd.read_csv('coatnet_3_rw_224_5fold.csv')
#       3 df2=pd.read_csv('vit_coat_eff_3fold.csv')
# ----> 4 df3=pd.read_csv('coatnet_3_rw_224_3fold.csv')
#
# ...

# %%
sum(df1['target']!=df2['target'])
# Out:
# 558

# %%
count=0
for i in range(len(df1)):
    if df1['target'][i]!=df2['target'][i] or df3['target'][i]!=df2['target'][i] or df1['target'][i]!=df3['target'][i]:
        print(i,df1['target'][i],df2['target'][i],df3['target'][i])
        count+=1

print(count)
# Out:
# 26 32 33 32
# 46 312 312 357
# 64 113 114 113
# 77 121 94 121
# 81 175 487 175
# 92 473 499 499
# 108 383 383 365
# 127 120 120 123
# 140 331 494 331
# 151 364 437 364
# 159 224 352 339
# 166 490 490 238
# 188 10 8 10
# 196 22 21 22
# 201 69 70 69
# 209 113 114 113
# 211 127 128 127
# 235 30 20 169
# 245 424 279 424
# 250 184 184 181
# 267 246 246 238
# 306 137 98 137
# 319 239 239 238
# 339 273 414 273
# 344 348 334 348
# 353 146 114 146
# 385 120 104 141
# 408 161 160 161
# 432 63 438 63
# 468 161 153 161
# 469 207 190 207
# 473 162 163 162
# 474 157 159 159
# 500 47 46 47
# 504 128 128 127
# 510 162 160 162
# 524 461 186 461
# 540 212 212 213
# 556 151 147 151
# 578 111 213 111
# 617 104 122 104
# 624 32 36 36
# 633 120 131 120
# 647 188 185 188
# 671 257 336 257
# 692 131 152 131
# 693 146 93 146
# 710 137 137 136
# 719 247 440 247
# 739 207 190 207
# 775 8 10 10
# 788 130 130 127
# 811 260 442 260
# 823 256 432 256
# 833 395 395 234
# 843 120 131 120
# 845 236 321 236
# ...

# %%
dat=pd.read_csv('/data/ephemeral/home/data/train.csv')

# %%
dat[dat['target']==226]
# Out:
#       class_name                image_path  target
# 746    n02692877  n02692877/sketch_28.JPEG     226
# 1491   n02692877  n02692877/sketch_50.JPEG     226
# 2087   n02692877  n02692877/sketch_39.JPEG     226
# 2200   n02692877   n02692877/sketch_8.JPEG     226
# 2318   n02692877  n02692877/sketch_18.JPEG     226
# 2769   n02692877   n02692877/sketch_4.JPEG     226
# 2968   n02692877  n02692877/sketch_21.JPEG     226
# 3235   n02692877   n02692877/sketch_7.JPEG     226
# 3887   n02692877  n02692877/sketch_27.JPEG     226
# 4323   n02692877  n02692877/sketch_33.JPEG     226
# 4371   n02692877  n02692877/sketch_14.JPEG     226
# 4863   n02692877  n02692877/sketch_25.JPEG     226
# 5471   n02692877  n02692877/sketch_29.JPEG     226
# 5492   n02692877  n02692877/sketch_43.JPEG     226
# 5745   n02692877  n02692877/sketch_34.JPEG     226
# 6199   n02692877  n02692877/sketch_31.JPEG     226
# 6926   n02692877  n02692877/sketch_35.JPEG     226
# ...

# %%
count=0
for i in range(len(df1)):
    if df1['target'][i]!=df2['target'][i] and df3['target'][i]!=df2['target'][i] and df1['target'][i]==df3['target'][i]:
        print(i,df1['target'][i],df2['target'][i],df3['target'][i])
        count+=1

print(count)
# Out:
# 26 32 33 32
# 64 113 114 113
# 77 121 94 121
# 81 175 487 175
# 140 331 494 331
# 151 364 437 364
# 188 10 8 10
# 196 22 21 22
# 201 69 70 69
# 209 113 114 113
# 211 127 128 127
# 245 424 279 424
# 306 137 98 137
# 339 273 414 273
# 344 348 334 348
# 353 146 114 146
# 408 161 160 161
# 432 63 438 63
# 468 161 153 161
# 469 207 190 207
# 473 162 163 162
# 500 47 46 47
# 510 162 160 162
# 524 461 186 461
# 556 151 147 151
# 578 111 213 111
# 617 104 122 104
# 633 120 131 120
# 647 188 185 188
# 671 257 336 257
# 692 131 152 131
# 693 146 93 146
# 719 247 440 247
# 739 207 190 207
# 811 260 442 260
# 823 256 432 256
# 843 120 131 120
# 845 236 321 236
# 938 127 128 127
# 948 461 380 461
# 983 463 482 463
# 1049 94 95 94
# 1056 190 207 190
# 1066 374 281 374
# 1128 232 399 232
# 1161 69 70 69
# 1164 433 326 433
# 1172 171 93 171
# 1175 449 207 449
# 1211 326 492 326
# 1221 404 403 404
# 1230 123 164 123
# 1235 119 151 119
# 1270 163 162 163
# 1272 127 128 127
# 1289 94 97 94
# ...

# %%
count=0
for i in range(len(df1)):
    if df1['target'][i]!=df2['target'][i] and df3['target'][i]!=df2['target'][i] and df1['target'][i]!=df3['target'][i]:
        print(i,df1['target'][i],df2['target'][i],df3['target'][i])
        count+=1

print(count)
# Out:
# 159 224 352 339
# 235 30 20 169
# 385 120 104 141
# 1104 165 163 162
# 1121 375 408 300
# 1191 32 34 41
# 1341 461 492 301
# 1442 147 142 126
# 1506 79 72 18
# 1614 494 375 266
# 1677 386 419 321
# 1683 419 427 331
# 1801 381 449 382
# 1877 130 111 207
# 2521 122 121 104
# 2526 379 451 263
# 2564 255 266 481
# 3061 32 34 41
# 3305 129 94 124
# 3418 368 366 383
# 3428 7 6 10
# 3487 161 441 426
# 3866 325 353 374
# 4230 118 111 107
# 4821 284 311 227
# 4865 421 236 230
# 4960 461 301 238
# 4995 323 416 406
# 5153 77 78 15
# 5172 250 423 295
# 5289 323 230 331
# 5322 236 326 433
# 5484 359 335 430
# 5548 350 308 290
# 5701 203 205 217
# 5746 145 338 181
# 5750 10 9 8
# 5781 350 308 290
# 6419 6 10 7
# 6596 143 104 141
# 6744 167 16 115
# 6819 134 162 59
# 6946 400 310 252
# 7049 247 440 421
# 7712 106 196 169
# 7920 330 228 273
# 7951 468 489 467
# 8026 381 382 272
# 8114 153 160 161
# 8121 329 488 461
# 8262 25 31 392
# 8301 16 396 115
# 8375 290 259 308
# 8442 481 69 379
# ...

# %%
dat1=pd.read_csv('/data/ephemeral/home/Seungcheol/skf_model/0924_model_ensemble/result/coatnet/coatnet_predict.csv')
dat2=pd.read_csv('/data/ephemeral/home/Seungcheol/skf_model/0924_model_ensemble/result/vit/vit_predict.csv')
dat3=pd.read_csv('/data/ephemeral/home/Seungcheol/skf_model/0924_model_ensemble/result/efficientnet/efficientnet_predict.csv')

# %%
count=0
for i in range(len(dat1)):
    if dat1['target'][i]!=dat2['target'][i] and dat3['target'][i]!=dat2['target'][i] and dat1['target'][i]!=dat3['target'][i]:
        print(i,dat[dat['target']==dat1['target'][i]]['class_name'].iloc[0],dat[dat['target']==dat2['target'][i]]['class_name'].iloc[0],dat[dat['target']==dat3['target'][i]]['class_name'].iloc[0])
        count+=1

print(count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 for i in range(len(dat1)):
#       3     if dat1['target'][i]!=dat2['target'][i] and dat3['target'][i]!=dat2['target'][i] and dat1['target'][i]!=dat3['target'][i]:
# ----> 4         print(i,dat[dat['target']==dat1['target'][i]]['class_name'].iloc[0],dat[dat['target']==dat2['target'][i]]['class_name'].iloc[0],dat[dat['target']==dat3['target'][i]]['class_name'].iloc[0])
#       5         count+=1
#       7 print(count)
#
# NameError: name 'dat' is not defined

# %%
count=0
for i in range(len(dat1)):
    if dat1['target'][i]==dat2['target'][i] and dat3['target'][i]!=dat2['target'][i] and dat1['target'][i]!=dat3['target'][i]:
        print(i,dat1['target'][i],dat2['target'][i],dat3['target'][i])
        count+=1

print(count)
# Out:
# 27 151 151 129
# 33 375 375 425
# 34 236 236 342
# 37 351 351 385
# 47 197 197 198
# 62 184 184 182
# 106 438 438 454
# 112 171 171 5
# 117 294 294 394
# 124 150 150 249
# 160 359 359 308
# 167 431 431 371
# 173 133 133 101
# 204 74 74 77
# 208 136 136 138
# 257 458 458 399
# 279 18 18 200
# 295 165 165 153
# 319 239 239 238
# 325 102 102 90
# 327 331 331 404
# 340 167 167 257
# 346 19 19 29
# 356 26 26 23
# 380 382 382 366
# 392 393 393 416
# 401 54 54 52
# 410 248 248 42
# 417 407 407 441
# 432 438 438 63
# 437 219 219 157
# 440 363 363 394
# 455 53 53 77
# 461 261 261 273
# 473 163 163 167
# 474 159 159 157
# 485 296 296 230
# 499 485 485 321
# 513 403 403 404
# 526 104 104 140
# 530 298 298 409
# 550 7 7 10
# 586 446 446 345
# 598 126 126 128
# 607 240 240 446
# 612 389 389 454
# 620 136 136 137
# 624 36 36 32
# 625 110 110 195
# 636 206 206 209
# 646 12 12 56
# 647 185 185 208
# 671 336 336 374
# 699 11 11 15
# 716 218 218 214
# 731 170 170 173
# 732 401 401 466
# ...

# %%
count=0
for i in range(len(dat1)):
    if dat1['target'][i]!=dat2['target'][i] or dat3['target'][i] != dat2['target'][i] or dat1['target'][i]!=dat3['target'][i]:
        print(i,dat1['target'][i],dat2['target'][i],dat3['target'][i])
        count+=1

print(count)
# Out:
# 12 64 272 38
# 21 321 352 321
# 22 497 473 226
# 26 32 33 33
# 27 151 151 129
# 33 375 375 425
# 34 236 236 342
# 37 351 351 385
# 45 443 239 443
# 47 197 197 198
# 62 184 184 182
# 76 292 344 292
# 77 94 141 94
# 78 110 135 135
# 81 231 487 195
# 88 365 319 365
# 92 473 499 499
# 102 138 108 108
# 105 80 207 217
# 106 438 438 454
# 112 171 171 5
# 117 294 294 394
# 121 439 254 439
# 124 150 150 249
# 139 27 195 290
# 140 331 494 438
# 151 319 437 494
# 159 339 393 352
# 160 359 359 308
# 166 238 490 238
# 167 431 431 371
# 171 7 8 7
# 173 133 133 101
# 188 16 7 8
# 197 53 52 77
# 201 69 70 70
# 204 74 74 77
# 208 136 136 138
# 209 113 114 114
# 211 128 127 128
# 222 206 167 206
# 233 101 133 101
# 235 186 169 20
# 245 424 279 492
# 257 458 458 399
# 267 246 238 431
# 273 152 153 186
# 279 18 18 200
# 295 165 165 153
# 306 136 98 136
# 307 124 129 129
# 319 239 239 238
# 325 102 102 90
# 327 331 331 404
# 339 273 447 348
# 340 167 167 257
# 344 334 363 348
# 346 19 19 29
# ...

# %%
count=0
for i in range(len(dat1)):
    if dat1['target'][i]!=dat2['target'][i] and dat3['target'][i] == dat2['target'][i] and dat1['target'][i]!=dat3['target'][i]:
        print(i,dat1['target'][i],dat2['target'][i],dat3['target'][i])
        count+=1

print(count)
# Out:
# 26 32 33 33
# 78 110 135 135
# 92 473 499 499
# 102 138 108 108
# 201 69 70 70
# 209 113 114 114
# 307 124 129 129
# 399 473 499 499
# 412 63 487 487
# 480 238 234 234
# 500 47 46 46
# 698 432 240 240
# 739 208 190 190
# 744 77 78 78
# 745 114 113 113
# 788 129 130 130
# 827 292 344 344
# 836 35 34 34
# 873 227 321 321
# 882 207 39 39
# 883 334 230 230
# 974 151 139 139
# 1005 126 127 127
# 1161 69 70 70
# 1172 171 93 93
# 1202 200 201 201
# 1230 123 164 164
# 1289 97 94 94
# 1329 110 117 117
# 1360 32 41 41
# 1380 474 471 471
# 1406 122 104 104
# 1424 101 155 155
# 1447 142 138 138
# 1456 145 143 143
# 1482 134 133 133
# 1610 266 463 463
# 1642 488 411 411
# 1756 371 39 39
# 1830 115 114 114
# 1864 122 104 104
# 1888 132 133 133
# 1933 124 125 125
# 1949 488 489 489
# 1990 303 412 412
# 2023 200 171 171
# 2072 153 155 155
# 2075 203 205 205
# 2092 126 128 128
# 2132 105 174 174
# 2263 356 287 287
# 2312 100 99 99
# 2313 208 209 209
# 2417 129 127 127
# 2423 217 215 215
# ...

# %%
count=0
for i in range(len(dat1)):
    if dat1['target'][i]!=dat2['target'][i] and dat3['target'][i] != dat2['target'][i] and dat1['target'][i]==dat3['target'][i]:
        print(i,dat1['target'][i],dat2['target'][i],dat3['target'][i])
        count+=1

print(count)
# Out:
# 21 321 352 321
# 45 443 239 443
# 76 292 344 292
# 77 94 141 94
# 88 365 319 365
# 121 439 254 439
# 166 238 490 238
# 171 7 8 7
# 211 128 127 128
# 222 206 167 206
# 233 101 133 101
# 306 136 98 136
# 359 324 436 324
# 451 451 192 451
# 488 427 308 427
# 504 128 127 128
# 510 160 162 160
# 517 233 231 233
# 576 485 489 485
# 580 484 325 484
# 591 312 298 312
# 601 124 119 124
# 617 122 92 122
# 634 2 3 2
# 638 106 105 106
# 678 208 206 208
# 719 440 247 440
# 751 258 420 258
# 756 403 404 403
# 759 115 114 115
# 769 487 63 487
# 785 94 140 94
# 816 432 240 432
# 823 432 265 432
# 845 236 321 236
# 848 410 446 410
# 879 121 123 121
# 908 186 187 186
# 932 106 146 106
# 970 497 499 497
# 989 489 62 489
# 1049 95 94 95
# 1062 325 415 325
# 1087 215 219 215
# 1094 137 136 137
# 1103 113 115 113
# 1175 207 347 207
# 1191 34 31 34
# 1192 46 47 46
# 1196 54 0 54
# 1221 403 404 403
# 1272 128 127 128
# 1324 67 470 67
# 1340 484 303 484
# 1377 487 36 487
# 1392 122 146 122
# ...

# %%
dat1.head()
# Out:
#    ID image_path  target
# 0   0     0.JPEG     328
# 1   1     1.JPEG     414
# 2   2     2.JPEG     493
# 3   3     3.JPEG      17
# 4   4     4.JPEG     388

# %%
a=dat1['target'][0]
b=dat2['target'][0]
c=dat2['target'][0]
values = [a, b, c] 
duplicates = set([x for x in values if values.count(x) > 1])

# %%
duplicates
# Out:
# {328}

# %%
dat_final=dat1.copy()

# %%
for i in range(len(dat1)):
    a=dat1['target'][i]
    b=dat2['target'][i]
    c=dat3['target'][i]
    values = [a, b, c]
    duplicates = set([x for x in values if values.count(x) > 1])
    if duplicates:
        dat_final.loc[i,'target']=duplicates
    else:
        dat_final.loc[i,'target']=a

# %%
dat_final.tail()
# Out:
#           ID  image_path  target
# 10009  10009  10009.JPEG     235
# 10010  10010  10010.JPEG     191
# 10011  10011  10011.JPEG     466
# 10012  10012  10012.JPEG     400
# 10013  10013  10013.JPEG     210

# %%
tk=pd.read_csv('/data/ephemeral/home/Seungcheol/skf_model/0924_model_ensemble/ensemble_result/vit_coat_eff_3fold.csv')

# %%
tk.head()
# Out:
#    ID image_path  target
# 0   0     0.JPEG     328
# 1   1     1.JPEG     414
# 2   2     2.JPEG     493
# 3   3     3.JPEG      17
# 4   4     4.JPEG     388

# %%
sum(tk['target']!=dat_final['target'])
# Out:
# 367

# %%
dat_final.to_csv('dat_final.csv')

# %%
coatnet=pd.read_csv('/data/ephemeral/home/Seungcheol/skf_model/0924_model_ensemble/ensemble_result/coatnet_3_rw_224_5fold_softmax.csv')
coatnet_softmax=coatnet.loc[:,'S0':'S499']
coatnet.head()
# Out:
#    ID image_path  target        S0        S1        S2        S3        S4  \
# 0   0     0.JPEG     328  0.000105  0.000106  0.000157  0.000157  0.000035
# 1   1     1.JPEG     414  0.000050  0.000156  0.000127  0.000200  0.000042
# 2   2     2.JPEG     493  0.000363  0.000445  0.000246  0.000257  0.001002
# 3   3     3.JPEG      17  0.000211  0.000160  0.000093  0.000106  0.000195
# 4   4     4.JPEG     388  0.000032  0.000034  0.000141  0.000080  0.000071
#
#          S5        S6  ...      S490      S491      S492      S493      S494  \
# 0  0.000141  0.000079  ...  0.000060  0.000151  0.000042  0.000059  0.000125
# 1  0.000118  0.000080  ...  0.000459  0.000122  0.000141  0.000678  0.000119
# 2  0.043710  0.000305  ...  0.000264  0.001329  0.000216  0.596700  0.001010
# 3  0.000146  0.000079  ...  0.000128  0.000063  0.000049  0.000140  0.000149
# 4  0.000069  0.000053  ...  0.000090  0.000037  0.000055  0.000040  0.000034
#
#        S495      S496      S497      S498      S499
# ...

# %%
ens=pd.read_csv('/data/ephemeral/home/Seungcheol/skf_model/0924_model_ensemble/ensemble_result/vit_coat_eff_5fold_softmax.csv')
ens_softmax=ens.loc[:,'S0':'S499']
ens.head()
# Out:
#    ID image_path  target        S0        S1        S2        S3        S4  \
# 0   0     0.JPEG     328  0.000032  0.000048  0.000096  0.000155  0.000077
# 1   1     1.JPEG     414  0.000034  0.000073  0.000080  0.000071  0.000035
# 2   2     2.JPEG     493  0.000449  0.000199  0.000515  0.000138  0.001516
# 3   3     3.JPEG      17  0.000371  0.000044  0.000062  0.000073  0.000365
# 4   4     4.JPEG     388  0.000524  0.000247  0.000332  0.000086  0.000126
#
#          S5        S6  ...      S490      S491      S492      S493      S494  \
# 0  0.000044  0.000058  ...  0.000088  0.000128  0.000094  0.000194  0.000042
# 1  0.000226  0.000085  ...  0.000113  0.000065  0.000030  0.000250  0.000074
# 2  0.009679  0.000456  ...  0.000201  0.001304  0.000223  0.517700  0.000882
# 3  0.000107  0.000063  ...  0.000095  0.000105  0.000080  0.000335  0.000072
# 4  0.000233  0.000130  ...  0.000040  0.000131  0.001028  0.000148  0.000064
#
#        S495      S496      S497      S498      S499
# ...

# %%
eff=pd.read_csv('/data/ephemeral/home/Seungcheol/skf_model/0924_model_ensemble/ensemble_result/efficientnet_b4_5fold_softmax.csv')
eff_softmax=eff.loc[:,'S0':'S499']
eff.head()
# Out:
#    ID image_path  target        S0        S1        S2        S3        S4  \
# 0   0     0.JPEG     328  0.000054  0.000110  0.000067  0.000113  0.000180
# 1   1     1.JPEG     414  0.000099  0.000083  0.000132  0.000124  0.000048
# 2   2     2.JPEG     493  0.000390  0.000125  0.000180  0.000109  0.001365
# 3   3     3.JPEG      17  0.000346  0.000126  0.000144  0.000109  0.000333
# 4   4     4.JPEG     388  0.000116  0.000111  0.000144  0.000061  0.000103
#
#          S5        S6  ...      S490      S491      S492      S493      S494  \
# 0  0.000081  0.000122  ...  0.000123  0.000061  0.000080  0.000224  0.000152
# 1  0.000162  0.000240  ...  0.000345  0.000123  0.000104  0.000329  0.000164
# 2  0.000473  0.000927  ...  0.000482  0.001511  0.000510  0.583000  0.001644
# 3  0.000068  0.000127  ...  0.000088  0.000118  0.000114  0.000285  0.000114
# 4  0.000396  0.000204  ...  0.000105  0.000164  0.000125  0.000112  0.000103
#
#        S495      S496      S497      S498      S499
# ...

# %%
vit=pd.read_csv("/data/ephemeral/home/Seungcheol/skf_model/0924_model_ensemble/ensemble_result/vit_large_patch16_224.augreg_in21k_ft_in1k_5fold_softmax.csv")
vit_softmax=vit.loc[:,'S0':'S499']
vit.tail()
# Out:
#           ID  image_path  target        S0        S1        S2        S3  \
# 10009  10009  10009.JPEG     235  0.000023  0.000054  0.000140  0.000031
# 10010  10010  10010.JPEG     191  0.000049  0.000067  0.000035  0.000149
# 10011  10011  10011.JPEG     466  0.000888  0.000316  0.000695  0.000431
# 10012  10012  10012.JPEG     258  0.000149  0.000123  0.000239  0.000143
# 10013  10013  10013.JPEG     210  0.000116  0.000031  0.000042  0.000034
#
#              S4        S5        S6  ...      S490      S491      S492  \
# 10009  0.000075  0.000156  0.000186  ...  0.000036  0.000045  0.000057
# 10010  0.000864  0.000662  0.000411  ...  0.000063  0.000035  0.000009
# 10011  0.000410  0.000960  0.001031  ...  0.000379  0.000040  0.000953
# 10012  0.000940  0.000278  0.000588  ...  0.000691  0.000131  0.000193
# 10013  0.000020  0.000164  0.000115  ...  0.000010  0.000010  0.000033
#
#            S493      S494      S495      S496      S497      S498      S499
# ...

# %%
final=0.3*eff_softmax+0.3*vit_softmax+0.4*coatnet_softmax
#final=eff_softmax+vit_softmax+coatnet_softmax

# %%
final
# Out:
#              S0        S1        S2        S3        S4        S5        S6  \
# 0      0.000074  0.000125  0.000090  0.000139  0.000140  0.000097  0.000085
# 1      0.000062  0.000237  0.000121  0.000129  0.000043  0.000117  0.000148
# 2      0.000614  0.000283  0.000180  0.000211  0.001575  0.017770  0.000512
# 3      0.000271  0.000113  0.000099  0.000084  0.000260  0.000115  0.000114
# 4      0.000081  0.000083  0.000130  0.000128  0.000074  0.000175  0.000102
# ...         ...       ...       ...       ...       ...       ...       ...
# 10009  0.000232  0.000312  0.000376  0.000512  0.000438  0.000296  0.000323
# 10010  0.000311  0.000233  0.000256  0.001701  0.001217  0.000825  0.001002
# 10011  0.001447  0.000744  0.000738  0.001383  0.000579  0.000780  0.000711
# 10012  0.000374  0.000408  0.000925  0.000332  0.000444  0.000316  0.000511
# 10013  0.000443  0.000136  0.000190  0.000121  0.000275  0.000411  0.000179
#
# ...

# %%
final.values.argmax(axis=1)
# Out:
# array([328, 414, 493, ..., 466, 400, 210])

# %%
test_info = pd.read_csv('/data/ephemeral/home/data/test.csv')
test_info.head()
# Out:
#   image_path
# 0     0.JPEG
# 1     1.JPEG
# 2     2.JPEG
# 3     3.JPEG
# 4     4.JPEG

# %%
test_info['target']=final.values.argmax(axis=1)
test_info.head()
# Out:
#   image_path  target
# 0     0.JPEG     328
# 1     1.JPEG     414
# 2     2.JPEG     493
# 3     3.JPEG      17
# 4     4.JPEG     388

# %%
test_info.to_csv('ensemble3.csv')
